# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
mrp = pd.read_csv("https://raw.githubusercontent.com/Premalatha-success/-Practice/main/HousePrices.csv")

# %%
mrp.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
mrp.shape
# Out:
# (1460, 81)

# %%
mrp.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
mrp.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
mrp.sample(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1354  1355          60       RL          NaN    10316   Pave   NaN      IR1
# 148    149          20       RL         63.0     7500   Pave   NaN      Reg
# 1205  1206          20       RL         90.0    14684   Pave   NaN      IR1
# 1369  1370          20       RL         48.0    10635   Pave   NaN      IR2
# 857    858          60       RL         65.0     8125   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 1354         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 148          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1205         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1369         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 857          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
mrp.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
mrp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
mrp.median()
# Out:
# Id                  730.5
# MSSubClass           50.0
# LotFrontage          69.0
# LotArea            9478.5
# OverallQual           6.0
# OverallCond           5.0
# YearBuilt          1973.0
# YearRemodAdd       1994.0
# MasVnrArea            0.0
# BsmtFinSF1          383.5
# BsmtFinSF2            0.0
# BsmtUnfSF           477.5
# TotalBsmtSF         991.5
# 1stFlrSF           1087.0
# 2ndFlrSF              0.0
# LowQualFinSF          0.0
# GrLivArea          1464.0
# BsmtFullBath          0.0
# BsmtHalfBath          0.0
# FullBath              2.0
# HalfBath              0.0
# BedroomAbvGr          3.0
# KitchenAbvGr          1.0
# TotRmsAbvGrd          6.0
# Fireplaces            1.0
# GarageYrBlt        1980.0
# GarageCars            2.0
# GarageArea          480.0
# WoodDeckSF            0.0
# OpenPorchSF          25.0
# EnclosedPorch         0.0
# 3SsnPorch             0.0
# ScreenPorch           0.0
# PoolArea              0.0
# MiscVal               0.0
# ...

# %%
mrp.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
mrp.drop(["MSZoning","Street","Alley","LotShape","LandContour","Utilities","BsmtFinType2","LotConfig","LandSlope","Neighborhood","Condition1","Condition2","BldgType","HouseStyle","ExterQual","ExterCond","Foundation","BsmtQual","BsmtCond","BsmtExposure","BsmtFinType1","RoofStyle","RoofMatl","Exterior1st","Exterior2nd","MasVnrType","KitchenQual","Functional","FireplaceQu","GarageType","GarageFinish","GarageQual","GarageCond","PavedDrive","PoolQC","Fence","MiscFeature","SaleType","SaleCondition","Heating","HeatingQC","CentralAir","Electrical"],axis=1,inplace=True)

# %%
mrp.drop(["LotFrontage","GarageYrBlt","MasVnrArea"],axis=1,inplace=True)

# %%
mrp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 35 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   LotArea        1460 non-null   int64
#  3   OverallQual    1460 non-null   int64
#  4   OverallCond    1460 non-null   int64
#  5   YearBuilt      1460 non-null   int64
#  6   YearRemodAdd   1460 non-null   int64
#  7   BsmtFinSF1     1460 non-null   int64
#  8   BsmtFinSF2     1460 non-null   int64
#  9   BsmtUnfSF      1460 non-null   int64
#  10  TotalBsmtSF    1460 non-null   int64
#  11  1stFlrSF       1460 non-null   int64
#  12  2ndFlrSF       1460 non-null   int64
#  13  LowQualFinSF   1460 non-null   int64
#  14  GrLivArea      1460 non-null   int64
#  15  BsmtFullBath   1460 non-null   int64
#  16  BsmtHalfBath   1460 non-null   int64
#  17  FullBath       1460 non-null   int64
# ...

# %%
mrp.sample(5)
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 265    266          20    12090            6            6       1981
# 240    241          20     9000            8            5       2008
# 1380  1381          30     8212            3            3       1914
# 1317  1318         120     4230            7            5       2006
# 1076  1077          50    10800            5            8       1936
#
#       YearRemodAdd  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  WoodDeckSF  \
# 265           1981         588         228        606  ...         276
# 240           2008        1078           0        488  ...         144
# 1380          1950         203           0        661  ...           0
# 1317          2007           0           0       1352  ...           0
# 1076          1989         626           0        170  ...         436
#
#       OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  \
# ...

# %%
X = mrp.drop(['SalePrice'],axis=1)
y = mrp[['SalePrice']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.30, random_state=1)

# %%
reg_model = LinearRegression()
reg_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
reg_model.score(X_train, y_train)
# Out:
# 0.7890032739521533

# %%
reg_model.score(X_test, y_test)
# Out:
# 0.8259397191703929

# %%
# mrp_num = mrp.select_dtypes(np.number)
# sns.pairplot(data = mrp_num)
# #sns.pairplot(mrp,diag_kind='kde')

# %%
print("Feature set size:",X.shape)
print("Variable set size:",y.shape)
# Out:
# Feature set size: (1460, 34)
# Variable set size: (1460, 1)

# %%
print("Train set size of X:",X_train.shape)
print("Train set size of y:",y_train.shape)
# Out:
# Train set size of X: (1022, 34)
# Train set size of y: (1022, 1)

# %%
print("Test set size of X:",X_test.shape)
print("Test set size of Y:",y_test.shape)
# Out:
# Test set size of X: (438, 34)
# Test set size of Y: (438, 1)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print("The intercept term of the linear model:", lm.intercept_)
# Out:
# The intercept term of the linear model: [1277509.89129792]

# %%
print("The coefficients of the linear model:", lm.coef_)
# Out:
# The coefficients of the linear model: [[-2.07670549e+00 -1.52813699e+02  4.45936085e-01  1.79078431e+04
#    5.01639489e+03  3.33375761e+02  1.26816966e+02  8.71402139e+00
#   -5.11486798e-01  5.74897958e-01  8.77743253e+00  1.05958224e+01
#    8.33828662e+00  6.27801663e+00  2.52121256e+01  9.15390690e+03
#    8.34584282e+03  7.88257809e+03  9.58597348e+01 -9.24841723e+03
#   -1.33296113e+04  7.09742285e+03  5.17134840e+03  1.28405805e+04
#   -5.21346018e-02  3.69953094e+01  1.12609845e+00  2.16769583e+01
#   -9.88928878e+00  7.44309107e+01 -1.36187254e+02 -4.77187254e-01
#   -4.17609795e+02 -1.12346223e+03]]

# %%
train_pred = lm.predict(X_train)

# %%
metrics.mean_squared_error(y_train,train_pred)
# Out:
# 1255151174.6688917

# %%
test_pred = lm.predict(X_test)

# %%
metrics.mean_squared_error(y_test,test_pred)
# Out:
# 1242843114.5232518

# %%
metrics.mean_absolute_error(y_train,train_pred)
# Out:
# 21578.550084567643

# %%
np.sqrt(metrics.mean_squared_error(y_train,train_pred))
# Out:
# 35428.11277317622

# %%
predictions = lm.predict(X_test)
print ("Type of the predicted object:", type(predictions))
print ("Size of the predicted object:", predictions.shape)
# Out:
# Type of the predicted object: <class 'numpy.ndarray'>
# Size of the predicted object: (438, 1)

# %%
print("Mean absolute error (MAE):", metrics.mean_absolute_error(y_test,predictions))
print("Mean square error (MSE):", metrics.mean_squared_error(y_test,predictions))
print("Root mean square error (RMSE):", np.sqrt(metrics.mean_squared_error(y_test,predictions)))
# Out:
# Mean absolute error (MAE): 22594.16804826985
# Mean square error (MSE): 1242843114.5232518
# Root mean square error (RMSE): 35253.980123147114

# %%
print("R-squared value of predictions:",round(metrics.r2_score(y_test,predictions),3))
# Out:
# R-squared value of predictions: 0.826

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn import linear_model

poly = PolynomialFeatures(degree=1,interaction_only=True)
X_train2 = poly.fit_transform(X_train)
X_test2 = poly.fit_transform(X_test)

poly_clf = linear_model.LinearRegression()
poly_clf.fit(X_train2, y_train)
y_pred = poly_clf.predict(X_test2)

# %%
print(poly_clf.score(X_train2,y_train))
# Out:
# 0.7890032739521532

# %%
print(poly_clf.score(X_test2, y_test))
# Out:
# 0.8259397191703888

# %%
plt.figure(figsize=(10,7))
sns.heatmap(mrp.corr(),annot=True,linewidths=3)
# Out:
# <AxesSubplot:>

# %%
mrp.corr()
# Out:
#                      Id  MSSubClass   LotArea  OverallQual  OverallCond  \
# Id             1.000000    0.011156 -0.033226    -0.028365     0.012609
# MSSubClass     0.011156    1.000000 -0.139781     0.032628    -0.059316
# LotArea       -0.033226   -0.139781  1.000000     0.105806    -0.005636
# OverallQual   -0.028365    0.032628  0.105806     1.000000    -0.091932
# OverallCond    0.012609   -0.059316 -0.005636    -0.091932     1.000000
# YearBuilt     -0.012713    0.027850  0.014228     0.572323    -0.375983
# YearRemodAdd  -0.021998    0.040581  0.013788     0.550684     0.073741
# BsmtFinSF1    -0.005024   -0.069836  0.214103     0.239666    -0.046231
# BsmtFinSF2    -0.005968   -0.065649  0.111170    -0.059119     0.040229
# BsmtUnfSF     -0.007940   -0.140759 -0.002618     0.308159    -0.136841
# TotalBsmtSF   -0.015415   -0.238518  0.260833     0.537808    -0.171098
# 1stFlrSF       0.010496   -0.251758  0.299475     0.476224    -0.144203
# ...

# %%
mrp['SalePrice'].plot.hist(bins=25,figsize=(8,4))
# Out:
# <AxesSubplot:ylabel='Frequency'>
